# %%
import pandas as pd

# %%
df = pd.read_csv('../files/importaciones_2013.csv', parse_dates=['date'])

# %%
pd.options.display.max_columns = 50
df.head()
# Out:
#         date tip_import       fob    flete  insurance       cif  salvaguardia  \
# 0 2013-03-26  IMP.GRAL.  2240.500  515.500     27.560  2783.560           0.0
# 1 2013-05-13  IMP.GRAL.   405.443   49.271      4.231   458.945           0.0
# 2 2013-06-17  IMP.GRAL.   315.680    6.750      3.380   325.810           0.0
# 3 2013-01-15  IMP.GRAL.   950.221   11.767      2.415   964.403           0.0
# 4 2013-02-26  IMP.GRAL.  5741.360   49.700      3.080  5794.140           0.0
#
#    salvaguardia_espec  fodinfa  ice_advalorem  ice_espec     iva  advalorem  \
# 0                 0.0    13.89            0.0        0.0  369.04     278.31
# 1                 0.0     1.92            0.0        0.0   56.59      61.23
# 2                 0.0     1.62            0.0        0.0   47.11      65.16
# 3                 0.0     4.85            0.0        0.0  117.14       0.00
# 4                 0.0    28.96            0.0        0.0  698.76       0.00
#
#    advalorem_espec iso                         pais  chap  duties  distr_code  \
# 0              0.0  BR                       Brasil    76  661.24          19
# 1              0.0  GB  Reino Unido De Gran Bretaña    39  119.74          19
# 2              0.0  BE                      Belgica    58  113.89          19
# 3              0.0  CN                        China    85  121.99          19
# 4              0.0  DE                     Alemania    84  727.72          19
#
#         distr_name    cty_ref  \
# 0  Guayaquil-Aereo  Guayaquil
# 1  Guayaquil-Aereo  Guayaquil
# 2  Guayaquil-Aereo  Guayaquil
# 3  Guayaquil-Aereo  Guayaquil
# 4  Guayaquil-Aereo  Guayaquil
#
#                                               titulo  cty_lat  cty_lng  \
# 0                        Aluminio y sus manufacturas  -2.1833 -79.8833
# 1                        Plástico y sus manufacturas  -2.1833 -79.8833
# 2   Tejidos especiales; superficies textiles con ...  -2.1833 -79.8833
# 3   Máquinas, aparatos y material eléctrico, y su...  -2.1833 -79.8833
# 4   Reactores nucleares, calderas, máquinas, apar...  -2.1833 -79.8833
#
#     pais_lat    pais_lng
# 0 -14.235004  -51.925280
# 1  55.378051   -3.435973
# 2  50.503887    4.469936
# 3  35.861660  104.195397
# 4  51.165691   10.451526

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                30000 non-null  datetime64[ns]
#  1   tip_import          30000 non-null  object
#  2   fob                 30000 non-null  float64
#  3   flete               30000 non-null  float64
#  4   insurance           30000 non-null  float64
#  5   cif                 30000 non-null  float64
#  6   salvaguardia        30000 non-null  float64
#  7   salvaguardia_espec  30000 non-null  float64
#  8   fodinfa             30000 non-null  float64
#  9   ice_advalorem       30000 non-null  float64
#  10  ice_espec           30000 non-null  float64
#  11  iva                 30000 non-null  float64
#  12  advalorem           30000 non-null  float64
#  13  advalorem_espec     30000 non-null  float64
#  14  iso                 30000 non-null  object
#  15  pais                29995 non-null  object
#  16  chap                30000 non-null  int64
#  17  duties              30000 non-null  float64
#  18  distr_code          30000 non-null  int64
#  19  distr_name          30000 non-null  object
#  20  cty_ref             30000 non-null  object
#  21  titulo              30000 non-null  object
#  22  cty_lat             30000 non-null  float64
#  23  cty_lng             30000 non-null  float64
#  24  pais_lat            29925 non-null  float64
#  25  pais_lng            29925 non-null  float64
# dtypes: datetime64[ns](1), float64(17), int64(2), object(6)
# memory usage: 6.0+ MB

# %%
df.groupby([
    df['date'].dt.strftime('%Y-%m'),
    'tip_import', 'iso', 'pais', 'pais_lat', 'pais_lng',
    'distr_code', 'distr_name', 'cty_ref', 'cty_lat', 'cty_lng',
    'titulo', 'chap'
]).agg({
    'fob' : 'sum',
    'flete' : 'sum',
    'insurance' : 'sum',
    'cif' : 'sum', 
    'salvaguardia' : 'sum',
    'salvaguardia_espec' : 'sum',
    'fodinfa' : 'sum', 
    'ice_advalorem' : 'sum',
    'ice_espec' : 'sum',
    'iva' : 'sum', 
    'advalorem' : 'sum', 
    'advalorem_espec' : 'sum',
    'duties': 'sum'
}).reset_index()
# Out:
#          date tip_import iso                               pais   pais_lat  \
# 0     2013-01  IMP.GRAL.  AR                          Argentina -38.416097
# 1     2013-01  IMP.GRAL.  AR                          Argentina -38.416097
# 2     2013-01  IMP.GRAL.  AR                          Argentina -38.416097
# 3     2013-01  IMP.GRAL.  AR                          Argentina -38.416097
# 4     2013-01  IMP.GRAL.  AR                          Argentina -38.416097
# ...       ...        ...  ..                                ...        ...
# 9019  2013-12  IMP.SMPL.  US                     Estados Unidos  37.090240
# 9020  2013-12  IMP.SMPL.  US                     Estados Unidos  37.090240
# 9021  2013-12  IMP.SMPL.  US                     Estados Unidos  37.090240
# 9022  2013-12  IMP.SMPL.  VE  Venezuela, Bolivarian Republic Of   6.423750
# 9023  2013-12  IMP.SMPL.  VN                            Vietnam  14.058324
#
#         pais_lng  distr_code          distr_name    cty_ref  cty_lat  cty_lng  \
# 0     -63.616672          19     Guayaquil-Aereo  Guayaquil  -2.1833 -79.8833
# 1     -63.616672          19     Guayaquil-Aereo  Guayaquil  -2.1833 -79.8833
# 2     -63.616672          19     Guayaquil-Aereo  Guayaquil  -2.1833 -79.8833
# 3     -63.616672          28  Guayaquil-Maritimo  Guayaquil  -2.1833 -79.8833
# 4     -63.616672          28  Guayaquil-Maritimo  Guayaquil  -2.1833 -79.8833
# ...          ...         ...                 ...        ...      ...      ...
# 9019  -95.712891          55               Quito      Quito  -0.2186 -78.5097
# 9020  -95.712891          55               Quito      Quito  -0.2186 -78.5097
# 9021  -95.712891          55               Quito      Quito  -0.2186 -78.5097
# 9022  -66.589730          19     Guayaquil-Aereo  Guayaquil  -2.1833 -79.8833
# 9023  108.277199          19     Guayaquil-Aereo  Guayaquil  -2.1833 -79.8833
#
#                                                  titulo  chap         fob  \
# 0      Aceites esenciales y resinoides; preparacione...    33    2401.720
# 1                             Caucho y sus manufacturas    40     550.500
# 2                                 Manufacturas diversas    96    6743.499
# 3      Papel y cartón; manufacturas de pasta de celu...    48       5.880
# 4                           Plástico y sus manufacturas    39  242611.780
# ...                                                 ...   ...         ...
# 9019   Reactores nucleares, calderas, máquinas, apar...    84   42679.210
# 9020   Tejidos especiales; superficies textiles con ...    58    1319.400
# 9021   Vehículos automóviles, tractores, velocípedos...    87    3975.750
# 9022   Instrumentos y aparatos de óptica, fotografía...    90     214.200
# 9023   Extractos curtientes o tintóreos; taninos y s...    32      10.500
#
#          flete  insurance         cif  salvaguardia  salvaguardia_espec  \
# 0      615.900     30.156    3047.776           0.0                 0.0
# 1       14.931      1.882     567.313           0.0                 0.0
# 2     1410.430      6.607    8160.536           0.0                 0.0
# 3        0.390      0.040       6.310           0.0                 0.0
# 4     6115.609    933.948  249661.337           0.0                 0.0
# ...        ...        ...         ...           ...                 ...
# 9019  1168.599    438.480   44286.289           0.0                 0.0
# 9020    28.635     13.480    1361.515           0.0                 0.0
# 9021   536.845     45.127    4557.722           0.0                 0.0
# 9022     0.630      2.150     216.980           0.0                 0.0
# 9023     7.120      0.160      17.780           0.0                 0.0
#
#       fodinfa  ice_advalorem  ice_espec       iva  advalorem  advalorem_espec  \
# 0       15.18            0.0        0.0    440.61     609.53              0.0
# 1        2.83            0.0        0.0     75.15      56.16              0.0
# 2       40.80            0.0        0.0   1277.93    2448.15              0.0
# 3        0.03            0.0        0.0      0.87       0.94              0.0
# 4     1253.57            0.0        0.0  32517.50   18817.57              0.0
# ...       ...            ...        ...       ...        ...              ...
# 9019   221.00            0.0        0.0   5382.45     350.53              0.0
# 9020     6.80            0.0        0.0    196.87     272.30              0.0
# 9021    22.74            0.0        0.0    642.23     771.88              0.0
# 9022     1.08            0.0        0.0     26.16       0.00              0.0
# 9023     0.08            0.0        0.0      2.14       0.00              0.0
#
#         duties
# 0      1065.32
# 1       134.14
# 2      3766.88
# 3         1.84
# 4     52588.64
# ...        ...
# 9019   5953.98
# 9020    475.97
# 9021   1436.85
# 9022     27.24
# 9023      2.22
#
# [9024 rows x 26 columns]
